# %% [markdown]
# <a href="https://www.kaggle.com/code/wardaadann/car-review-sentiment-analysis-beginner-project?scriptVersionId=314364893" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Notebook of Car Review analyzer

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

for root, dirs, files in os.walk("/kaggle/input"):
    print(root)
    print(files)

# %% [markdown]
# ### 2. Load Dataset

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/datasets/wardaadann/car-reviews-analyzer-csv/sample_reviews.csv")
df.head()

# %% [markdown]
# ### 3. Basic Info

# %%
df.info()
df.describe()

# %% [markdown]
# ### 4. Check missing value

# %%
df.isnull().sum()

# %% [markdown]
# ### 5. Rating Distribution

# %%
df['rating'].value_counts().sort_index().plot(kind='bar')
plt.title("Rating Distribution")
plt.show()

# %% [markdown]
# ### 6.Simple Sentiment Logic (Rule-based)

# %%
def sentiment(rating):
    if rating >= 4:
        return "Positive"
    elif rating == 3:
        return "Neutral"
    else:
        return "Negative"

df['sentiment'] = df['rating'].apply(sentiment)
df.head()

# %% [markdown]
# ### 7.Sentiment Count Plot

# %%
df['sentiment'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Sentiment Distribution")
plt.show()

# %% [markdown]
# ### 8. Most Common Words

# %%
from wordcloud import WordCloud

text = " ".join(df['review_text'])
wordcloud = WordCloud(width=800, height=400).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
